# %% [markdown]
# <a href="https://colab.research.google.com/github/EzequielFelipeBorgelt/COLAB-Data-Analysis/blob/main/Python_e_Excel_Copy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Integração Python + Excel
#
# ### 2 formas:
#
# 1. Pandas
#     - Mais usada no geral
#     - Trata o Excel como uma base de dados
#     - Faz o que quiser com o arquivo
#     - Pode desfazer a estrutura original do arquivo, caso queira editar
#
# 2. Openpyxl
#     - Trata o Excel como uma planilha mesmo que pode ter várias coisas
#     - Edita "como se fosse um VBA"
#     - Menos eficiente
#     - Mantém mais a estrutura original do arquivo, mas cuidado porque não necessariamente tudo, então tem que testar

# %% [markdown]
# ### Desafio
#
# - Temos uma planilha de produtos e serviços. Com o aumento de imposto sobre os serviços, temos que atualizar o preço dos produtos impactados pela mudança.
#
# Novo Multiplicador Imposto: 1.5

# %%
# pandas
import pandas as pd

tabela = pd.read_excel("LOTES.xlsx")
#display(tabela.head(10))
#print(tabela.shape)
#display(tabela.describe())
#display(tabela.loc[1:2])
numero_lote = tabela.loc[tabela["LOTE_PEDIDO"]=="10011/1"]
#display(numero_lote)
agrupado_lote = numero_lote[["LOTE_PEDIDO",	"QTDE",	"BAIXADO",	"FISICO",	"PENDENTE",	"LOTE",	"TRANSITO", "ADIANTAR",	"FALTAS",	"CODREF",	"CORES",	"TECFORMA",	"TAMANHO",	"EMISSAO",	"ENTREGA"	,"PEDIDO"	,"FICHA"]].groupby(["LOTE_PEDIDO",	"CODREF",	"CORES",	"TECFORMA",	"TAMANHO",	"EMISSAO",	"ENTREGA"	,"PEDIDO"	,"FICHA",	"LOTE"]).sum()
display(agrupado_lote.head(60))
#agrupado_lote.to_excel("LOTES_V1.xlsx", index=False)
# Out:
#                                                                                              QTDE  ...  FALTAS
# LOTE_PEDIDO CODREF     CORES    TECFORMA TAMANHO EMISSAO    ENTREGA    PEDIDO FICHA LOTE           ...
# 10011/1     -BL102     PRETO    W        .13½L   23.11.2021 31.01.2022 25228  2     10011/1     1  ...      -1
#                                          .8 L    23.11.2021 31.01.2022 25228  2     10011/1     1  ...      -1
#             -BL178     PRETO    M        .10     23.11.2021 31.01.2022 25228  12    10011/1     1  ...      -1
#                                          .5½     23.11.2021 31.01.2022 25218  12    10011/1     1  ...      -1
#                                          .6      23.11.2021 31.01.2022 25228  12    10011/1     1  ...      -1
#                                          .7      23.11.2021 31.01.2022 25228  12    10011/1     1  ...      -1
# ...

# %%
# !pip install openpyxl=='3.0.0'
import openpyxl
# Out:
# ...
#      |████████████████████████████████| 172 kB 19.3 MB/s
# ...
#   Created wheel for openpyxl: filename=openpyxl-3.0.0-py2.py3-none-any.whl size=241207 sha256=f4f10e8e2d5fa4fdf9e4095da826f9efb9522eb42fdd9a2882e12ed94942c66e
#   Stored in directory: /root/.cache/pip/wheels/c7/64/ff/ce98f6e1d2701ae8e216c875da62feed2839ac8a3cae0ab8af
# Successfully built openpyxl
# ...
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# ...
